# %% [markdown]
# # Raw Data Discovery
# ## Who Is The Best Beatle?

# %%
import pandas as pd

beatles_catalog = pd.read_csv('data/raw_data/all_beatles_catalog.csv')
lennon_catalog = pd.read_csv('data/raw_data/all_lennon_catalog.csv')
mccartney_catalog = pd.read_csv('data/raw_data/all_mccartney_catalog.csv')
harrison_catalog = pd.read_csv('data/raw_data/all_Harrison_catalog.csv')
starr_catalog = pd.read_csv('data/raw_data/all_starr_catalog.csv')

beatles_billboard = pd.read_csv('data/raw_data/beatles_singles.csv')
lennon_billboard = pd.read_csv('data/raw_data/lennon_singles.csv')
mccartney_billboard = pd.read_csv('data/raw_data/mccartney_singles.csv')
harrison_billboard = pd.read_csv('data/raw_data/harrison_singles.csv')
starr_billboard = pd.read_csv('data/raw_data/starr_singles.csv')

lennon_producer = pd.read_csv('data/raw_data/lennon_as_producer.csv')
mccartney_producer = pd.read_csv('data/raw_data/mccartney_as_producer.csv')
harrison_producer = pd.read_csv('data/raw_data/harrison_as_producer.csv')
starr_producer = pd.read_csv('data/raw_data/starr_as_producer.csv')

top_500_songs = pd.read_json('data/raw_data/top_500_songs_2021.json')

top_500_albums = pd.read_csv('data/raw_data/top_500_albums_2023.csv')

top_spotify_2023 = pd.read_csv('data/raw_data/spotify_2023.csv', encoding='ISO-8859-1')
# speacial encoding required to oversome error related to Latin-1
# must convert code points to byte values
# if a code point larger than 255 is encountered, the string can’t be encoded into Latin-1

# %%
beatles_catalog
# Out:
#      Unnamed: 0                                 Song  \
# 0             0             "Across the Universe"[e]
# 1             1                      "Act Naturally"
# 2             2                 "All I've Got to Do"
# 3             3                      "All My Loving"
# 4             4                   "All Together Now"
# ..          ...                                  ...
# 208         208        "You Really Got a Hold on Me"
# 209         209                   "You Won't See Me"
# 210         210            "Your Mother Should Know"
# 211         211     "You're Going to Lose That Girl"
# 212         212  "You've Got to Hide Your Love Away"
#
#     Core catalogue release(s)                   Songwriter(s)  \
# 0      Let It Be Past Masters                Lennon McCartney
# 1                       Help!  Johnny Russell Voni Morrison †
# 2            With the Beatles                Lennon McCartney
# 3            With the Beatles                Lennon McCartney
# ...

# %%
lennon_catalog

# %%
mccartney_catalog

# %%
harrison_catalog

# %%
starr_catalog

# %%
beatles_billboard
#
# Out:
#     Unnamed: 0                              Song  \
# 0            1                   Twist And Shout
# 1            2                          Hey Jude
# 2            3       Got To Get You Into My Life
# 3            4           Come Together/Something
# 4            5          I Want To Hold Your Hand
# ..         ...                               ...
# 67          68                   There's A Place
# 68          69    Sie Liebt Dich (She Loves You)
# 69          70  I'm Happy Just To Dance With You
# 70          71                               Why
# 71          72                   The Inner Light
#
#                             Artist      Debute  Peak   Peak Date  Weeks
# 0                      The Beatles  2064-03-14     2  2064-04-04     26
# 1                      The Beatles  2068-09-14     1  2068-09-28     19
# 2                      The Beatles  1976-06-12     7  1976-07-24     16
# 3                      The Beatles  1969-10-18     1  1969-11-29     16
# ...

# %%
lennon_billboard
# Out:
#     Unnamed: 0                              Song  \
# 0            1         (Just Like) Starting Over
# 1            2                             Woman
# 2            3               Watching The Wheels
# 3            4  Whatever Gets You Thru The Night
# 4            5                    Nobody Told Me
# 5            6   Instant Karma (We All Shine On)
# 6            7                        MIND GAMES
# 7            8                          #9 Dream
# 8            9                       Cold Turkey
# 9           10                           Imagine
# 10          11               Give Peace A Chance
# 11          12               Power To The People
# 12          13                       Stand By Me
# 13          14                            Mother
# 14          15          Happy Xmas (War Is Over)
# 15          16                  I'm Steppin' Out
# 16          17  Woman Is The Nigger Of The World
# 17          18                       Jealous Guy
#
# ...

# %%
mccartney_billboard

# %%
harrison_billboard

# %%
starr_billboard

# %%
lennon_producer
# Out:
#      Unnamed: 0                                            Songs
# 0             1                                         Air Talk
# 1             2                                          Airmale
# 2             3                            Aisumasen (I'm Sorry)
# 3             4  Amerika (David Peel & The Lower East Side song)
# 4             5        Amsterdam (John Lennon and Yoko Ono song)
# ..          ...                                              ...
# 177         178                  Yellow Girl (Stand by for Life)
# 178         179                              Yes, I'm Your Angel
# 179         180                              You (Yoko Ono song)
# 180         181                              You Are Here (song)
# 181         182                   You're the One (Yoko Ono song)
#
# [182 rows x 2 columns]

# %%
mccartney_producer

# %%
harrison_billboard

# %%
starr_producer

# %%
top_500_songs
# Out:
#           id  position            artist                    title  year  \
# 0    1224837       500        Kanye West                 Stronger  2007
# 1    1224838       499      The Supremes                Baby Love  1964
# 2    1224839       498  Townes Van Zandt         Pancho and Lefty  1972
# 3    1224840       497             Lizzo              Truth Hurts  2017
# 4    1224841       496     Harry Nilsson              Without You  1971
# ..       ...       ...               ...                      ...   ...
# 495  1225333         5           Nirvana  Smells Like Teen Spirit  1991
# 496  1225334         4         Bob Dylan     Like a Rolling Stone  1965
# 497  1225335         3         Sam Cooke   A Change Is Gonna Come  1964
# 498  1225336         2      Public Enemy          Fight the Power  1989
# 499  1225337         1   Aretha Franklin                  Respect  1967
#
#                                                writers  \
# ...

# %%
top_500_albums
# Out:
#      Position           Artist                            Album Name  \
# 0           1      Marvin Gaye                     'What's Going On'
# 1           2   The Beach Boys                          'Pet Sounds'
# 2           3    Joni Mitchell                                'Blue'
# 3           4    Stevie Wonder            'Songs in the Key of Life'
# 4           5      The Beatles                          'Abbey Road'
# ..        ...              ...                                   ...
# 495       496          Shakira            'Dónde Están los Ladrones'
# 496       497  Various Artists   'The Indestructible Beat of Soweto'
# 497       498          Suicide                             'Suicide'
# 498       499            Rufus                Chaka Khan 'Ask Rufus'
# 499       500      Arcade Fire                            '﻿Funeral'
#
#             Label  Year                                             Critic
# ...

# %%
top_spotify_2023
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...
